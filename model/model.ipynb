# %%
# Initial imports
import pandas as pd
import joblib
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from pandas import get_dummies
# %matplotlib inline

# %%
# Load data into dataframe
student_df = pd.read_csv("../Resources/student_depression_dataset.csv")
student_df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
# Number of depressed students
dep_students = student_df[["Depression", "id"]].groupby("Depression").count()
dep_students
# Out:
#                id
# Depression
# 0           11565
# 1           16336

# %%
# Professions in dataset
student_df.Profession.value_counts()
# Out:
# Profession
# Student                     27870
# Architect                       8
# Teacher                         6
# 'Digital Marketer'              3
# 'Content Writer'                2
# Chef                            2
# Doctor                          2
# Pharmacist                      2
# 'Civil Engineer'                1
# 'UX/UI Designer'                1
# 'Educational Consultant'        1
# Manager                         1
# Lawyer                          1
# Entrepreneur                    1
# Name: count, dtype: int64

# %%
# Average academic pressure
ac_pres_avg = student_df.groupby(by=["Profession"])[["Academic Pressure"]].mean()
ac_pres_avg
# Out:
#                           Academic Pressure
# Profession
# 'Civil Engineer'                   5.000000
# 'Content Writer'                   5.000000
# 'Digital Marketer'                 3.666667
# 'Educational Consultant'           3.000000
# 'UX/UI Designer'                   3.000000
# Architect                          3.750000
# Chef                               2.500000
# Doctor                             4.000000
# Entrepreneur                       3.000000
# Lawyer                             4.000000
# Manager                            3.000000
# Pharmacist                         4.000000
# Student                            3.140617
# Teacher                            3.500000

# %%
# Unique cities in dataset
student_df.City.unique()
# Out:
# array(['Visakhapatnam', 'Bangalore', 'Srinagar', 'Varanasi', 'Jaipur',
#        'Pune', 'Thane', 'Chennai', 'Nagpur', 'Nashik', 'Vadodara',
#        'Kalyan', 'Rajkot', 'Ahmedabad', 'Kolkata', 'Mumbai', 'Lucknow',
#        'Indore', 'Surat', 'Ludhiana', 'Bhopal', 'Meerut', 'Agra',
#        'Ghaziabad', 'Hyderabad', 'Vasai-Virar', 'Kanpur', 'Patna',
#        'Faridabad', 'Delhi', 'Saanvi', 'M.Tech', 'Bhavna', "'Less Delhi'",
#        'City', '3.0', "'Less than 5 Kalyan'", 'Mira', 'Harsha', 'Vaanya',
#        'Gaurav', 'Harsh', 'Reyansh', 'Kibara', 'Rashi', 'ME', 'M.Com',
#        'Nalyan', 'Mihir', 'Nalini', 'Nandini', 'Khaziabad'], dtype=object)

# %%
# Define features
X = student_df.copy().drop(["Depression", "id"], axis=1)
X.head(20)
# Out:
#     Gender   Age           City Profession  Academic Pressure  Work Pressure  \
# 0     Male  33.0  Visakhapatnam    Student                5.0            0.0
# 1   Female  24.0      Bangalore    Student                2.0            0.0
# 2     Male  31.0       Srinagar    Student                3.0            0.0
# 3   Female  28.0       Varanasi    Student                3.0            0.0
# 4   Female  25.0         Jaipur    Student                4.0            0.0
# 5     Male  29.0           Pune    Student                2.0            0.0
# 6     Male  30.0          Thane    Student                3.0            0.0
# 7   Female  30.0        Chennai    Student                2.0            0.0
# 8     Male  28.0         Nagpur    Student                3.0            0.0
# 9     Male  31.0         Nashik    Student                2.0            0.0
# 10    Male  24.0         Nagpur    Student                3.0            0.0
# 11    Male  33.0       Vadodara    Student                3.0            0.0
# 12    Male  27.0         Kalyan    Student                5.0            0.0
# 13  Female  19.0         Rajkot    Student                2.0            0.0
# 14  Female  19.0         Kalyan    Student                5.0            0.0
# 15    Male  29.0       Srinagar    Student                3.0            0.0
# 16    Male  25.0         Nashik    Student                5.0            0.0
# 17  Female  20.0      Ahmedabad    Student                5.0            0.0
# 18    Male  19.0        Chennai    Student                2.0            0.0
# 19    Male  25.0         Kalyan    Student                3.0            0.0
#
#     CGPA  Study Satisfaction  Job Satisfaction       Sleep Duration  \
# 0   8.97                 2.0               0.0          '5-6 hours'
# 1   5.90                 5.0               0.0          '5-6 hours'
# 2   7.03                 5.0               0.0  'Less than 5 hours'
# 3   5.59                 2.0               0.0          '7-8 hours'
# 4   8.13                 3.0               0.0          '5-6 hours'
# 5   5.70                 3.0               0.0  'Less than 5 hours'
# 6   9.54                 4.0               0.0          '7-8 hours'
# 7   8.04                 4.0               0.0  'Less than 5 hours'
# 8   9.79                 1.0               0.0          '7-8 hours'
# 9   8.38                 3.0               0.0  'Less than 5 hours'
# 10  6.10                 3.0               0.0          '5-6 hours'
# 11  7.03                 4.0               0.0  'Less than 5 hours'
# 12  7.04                 1.0               0.0  'Less than 5 hours'
# 13  8.52                 4.0               0.0  'Less than 5 hours'
# 14  5.64                 5.0               0.0  'Less than 5 hours'
# 15  8.58                 3.0               0.0  'More than 8 hours'
# 16  6.51                 2.0               0.0  'Less than 5 hours'
# 17  7.25                 3.0               0.0          '5-6 hours'
# 18  7.83                 2.0               0.0          '7-8 hours'
# 19  9.93                 3.0               0.0          '5-6 hours'
#
#    Dietary Habits      Degree Have you ever had suicidal thoughts ?  \
# 0         Healthy     B.Pharm                                   Yes
# 1        Moderate         BSc                                    No
# 2         Healthy          BA                                    No
# 3        Moderate         BCA                                   Yes
# 4        Moderate      M.Tech                                   Yes
# 5         Healthy         PhD                                    No
# 6         Healthy         BSc                                    No
# 7       Unhealthy  'Class 12'                                    No
# 8        Moderate        B.Ed                                   Yes
# 9        Moderate         LLB                                   Yes
# 10       Moderate  'Class 12'                                   Yes
# 11        Healthy          BE                                   Yes
# 12       Moderate      M.Tech                                    No
# 13      Unhealthy  'Class 12'                                    No
# 14       Moderate  'Class 12'                                   Yes
# 15       Moderate      M.Tech                                   Yes
# 16      Unhealthy        M.Ed                                   Yes
# 17        Healthy  'Class 12'                                   Yes
# 18      Unhealthy  'Class 12'                                    No
# 19       Moderate        B.Ed                                    No
#
#     Work/Study Hours Financial Stress Family History of Mental Illness
# 0                3.0              1.0                               No
# 1                3.0              2.0                              Yes
# 2                9.0              1.0                              Yes
# 3                4.0              5.0                              Yes
# 4                1.0              1.0                               No
# 5                4.0              1.0                               No
# 6                1.0              2.0                               No
# 7                0.0              1.0                              Yes
# 8               12.0              3.0                               No
# 9                2.0              5.0                               No
# 10              11.0              1.0                              Yes
# 11              10.0              2.0                              Yes
# 12              10.0              1.0                              Yes
# 13               6.0              2.0                              Yes
# 14               4.0              5.0                              Yes
# 15              10.0              2.0                              Yes
# 16               2.0              5.0                              Yes
# 17              10.0              3.0                               No
# 18               6.0              3.0                               No
# 19               8.0              3.0                              Yes

# %%
# Define target
y = student_df["Depression"]
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: Depression, dtype: int64

# %%
# Use get dummies to change categorical data to True/False.
columns_to_dummy = ["Profession", "City", "Gender", "Sleep Duration", "Dietary Habits", "Degree", "Have you ever had suicidal thoughts ?", "Family History of Mental Illness", "Financial Stress"]
X_dummies = pd.get_dummies(X[columns_to_dummy], columns=columns_to_dummy)
X = pd.concat([X, X_dummies], axis=1)
X = X.drop(columns=columns_to_dummy, axis=1)
X
# Out:
#         Age  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0      33.0                5.0            0.0  8.97                 2.0
# 1      24.0                2.0            0.0  5.90                 5.0
# 2      31.0                3.0            0.0  7.03                 5.0
# 3      28.0                3.0            0.0  5.59                 2.0
# 4      25.0                4.0            0.0  8.13                 3.0
# ...     ...                ...            ...   ...                 ...
# 27896  27.0                5.0            0.0  5.75                 5.0
# 27897  27.0                2.0            0.0  9.40                 3.0
# 27898  31.0                3.0            0.0  6.61                 4.0
# 27899  18.0                5.0            0.0  6.88                 2.0
# 27900  27.0                4.0            0.0  9.24                 1.0
#
#        Job Satisfaction  Work/Study Hours  Profession_'Civil Engineer'  \
# 0                   0.0               3.0                        False
# 1                   0.0               3.0                        False
# 2                   0.0               9.0                        False
# 3                   0.0               4.0                        False
# 4                   0.0               1.0                        False
# ...                 ...               ...                          ...
# 27896               0.0               7.0                        False
# 27897               0.0               0.0                        False
# 27898               0.0              12.0                        False
# 27899               0.0              10.0                        False
# 27900               0.0               2.0                        False
#
#        Profession_'Content Writer'  Profession_'Digital Marketer'  ...  \
# 0                            False                          False  ...
# 1                            False                          False  ...
# 2                            False                          False  ...
# 3                            False                          False  ...
# 4                            False                          False  ...
# ...                            ...                            ...  ...
# 27896                        False                          False  ...
# 27897                        False                          False  ...
# 27898                        False                          False  ...
# 27899                        False                          False  ...
# 27900                        False                          False  ...
#
#        Have you ever had suicidal thoughts ?_No  \
# 0                                         False
# 1                                          True
# 2                                          True
# 3                                         False
# 4                                         False
# ...                                         ...
# 27896                                     False
# 27897                                      True
# 27898                                      True
# 27899                                     False
# 27900                                     False
#
#        Have you ever had suicidal thoughts ?_Yes  \
# 0                                           True
# 1                                          False
# 2                                          False
# 3                                           True
# 4                                           True
# ...                                          ...
# 27896                                       True
# 27897                                      False
# 27898                                      False
# 27899                                       True
# 27900                                       True
#
#        Family History of Mental Illness_No  \
# 0                                     True
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                     True
# ...                                    ...
# 27896                                False
# 27897                                False
# 27898                                 True
# 27899                                 True
# 27900                                False
#
#        Family History of Mental Illness_Yes  Financial Stress_1.0  \
# 0                                     False                  True
# 1                                      True                 False
# 2                                      True                  True
# 3                                      True                 False
# 4                                     False                  True
# ...                                     ...                   ...
# 27896                                  True                  True
# 27897                                  True                 False
# 27898                                 False                 False
# 27899                                 False                 False
# 27900                                  True                 False
#
#        Financial Stress_2.0  Financial Stress_3.0  Financial Stress_4.0  \
# 0                     False                 False                 False
# 1                      True                 False                 False
# 2                     False                 False                 False
# 3                     False                 False                 False
# 4                     False                 False                 False
# ...                     ...                   ...                   ...
# 27896                 False                 False                 False
# 27897                 False                  True                 False
# 27898                  True                 False                 False
# 27899                 False                 False                 False
# 27900                 False                  True                 False
#
#        Financial Stress_5.0  Financial Stress_?
# 0                     False               False
# 1                     False               False
# 2                     False               False
# 3                      True               False
# 4                     False               False
# ...                     ...                 ...
# 27896                 False               False
# 27897                 False               False
# 27898                 False               False
# 27899                  True               False
# 27900                 False               False
#
# [27901 rows x 122 columns]

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create scaler instance and fit to train dataset
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

# %%
# Scale data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create random forest binary classifier
rf_model = RandomForestClassifier(n_estimators=500, random_state=1)

# %%
# Fit model to scaled training data and y_train
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Make predictions for test data
predictions = rf_model.predict(X_test_scaled)

# %%
# Evaluate model using confusion matrix
conf_matrix = confusion_matrix(y_test, predictions)
conf_matrix_df = pd.DataFrame(
    conf_matrix,
    index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

# Calculate accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Display results of evaluation
print("Confusion Matrix")
display(conf_matrix_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         2247          615
# Actual 1          453         3661
# Accuracy Score : 0.8469036697247706
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81      2862
#            1       0.86      0.89      0.87      4114
#
#     accuracy                           0.85      6976
#    macro avg       0.84      0.84      0.84      6976
# weighted avg       0.85      0.85      0.85      6976

# %%
# Calculate feature importance of the model
importances = rf_model.feature_importances_

# Sort importances by value
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(0.13166102585448206, 'Academic Pressure'),
#  (0.11968977369673613, 'Have you ever had suicidal thoughts ?_No'),
#  (0.10891603451737061, 'Have you ever had suicidal thoughts ?_Yes'),
#  (0.06429242118558383, 'Age'),
#  (0.060375577363877005, 'CGPA'),
#  (0.05701155378463896, 'Work/Study Hours'),
#  (0.03668449226817565, 'Study Satisfaction'),
#  (0.030220633612777534, 'Financial Stress_5.0'),
#  (0.029148391675321222, 'Financial Stress_1.0'),
#  (0.016775021233697906, 'Dietary Habits_Unhealthy'),
#  (0.013186246564655446, 'Financial Stress_2.0'),
#  (0.013141378814288656, 'Dietary Habits_Healthy'),
#  (0.01087553293966067, 'Financial Stress_4.0'),
#  (0.010563301569310332, 'Gender_Female'),
#  (0.010540650401401192, 'Gender_Male'),
#  (0.010306433239859355, "Degree_'Class 12'"),
#  (0.01024994156168505, "Sleep Duration_'Less than 5 hours'"),
#  (0.00967965479372522, "Sleep Duration_'7-8 hours'"),
#  (0.009400272197941472, "Sleep Duration_'More than 8 hours'"),
#  (0.009127039559951216, "Sleep Duration_'5-6 hours'"),
#  (0.00895448523604476, 'Family History of Mental Illness_No'),
#  (0.00887405186475857, 'Family History of Mental Illness_Yes'),
#  (0.008089143470676966, 'Dietary Habits_Moderate'),
#  (0.007757843249200841, 'Financial Stress_3.0'),
#  (0.0053931813047546065, 'City_Srinagar'),
#  (0.005278981081248197, 'City_Kalyan'),
#  (0.0051035583283831195, 'Degree_BCA'),
#  (0.004875489801756476, 'Degree_B.Ed'),
#  (0.0048273480593944516, 'City_Hyderabad'),
#  (0.004815240745321921, 'City_Vasai-Virar'),
#  (0.004770050337892858, 'Degree_B.Com'),
#  (0.004633744496523553, 'City_Agra'),
#  (0.0046024249720916476, 'City_Pune'),
#  (0.004429533534331995, 'Degree_MSc'),
#  (0.0044114765120903555, 'City_Lucknow'),
#  (0.004358741099132262, 'City_Jaipur'),
#  (0.004332465770678117, 'City_Chennai'),
#  (0.004153236021444649, 'City_Surat'),
#  (0.004128934226512833, 'City_Bhopal'),
#  (0.004128539212156547, 'Degree_B.Arch'),
#  (0.00411754230085162, 'City_Patna'),
#  (0.004105432888539557, 'City_Visakhapatnam'),
#  (0.00410009569651591, 'City_Ludhiana'),
#  (0.004088147337405614, 'Degree_MCA'),
#  (0.004055985120341144, 'City_Ahmedabad'),
#  (0.004049386954546754, 'City_Thane'),
#  (0.003917085339689241, 'Degree_B.Tech'),
#  (0.003912219440933691, 'Degree_BHM'),
#  (0.003774233492412308, 'City_Kolkata'),
#  (0.003675651800757109, 'City_Rajkot'),
#  (0.003626921949865101, 'Degree_M.Tech'),
#  (0.0036085342279242776, 'Degree_B.Pharm'),
#  (0.0035963737935160813, 'Degree_BSc'),
#  (0.0035387857797876377, 'City_Bangalore'),
#  (0.003446233935774225, 'City_Meerut'),
#  (0.0034361350737157413, 'Degree_MBBS'),
#  (0.0033672416520153913, 'Degree_BE'),
#  (0.0033494028091692603, 'City_Mumbai'),
#  (0.0032799115680956273, 'City_Vadodara'),
#  (0.0032755900731451285, 'City_Delhi'),
#  (0.0032719841017510272, 'City_Ghaziabad'),
#  (0.003257963909401801, 'City_Nagpur'),
#  (0.0030686017846260107, 'City_Indore'),
#  (0.003067485204548864, 'Degree_BBA'),
#  (0.0030463965780600684, 'Degree_LLB'),
#  (0.0030226734910312808, 'Degree_BA'),
#  (0.0029980176750686767, 'Degree_M.Ed'),
#  (0.0029896291623314974, 'Degree_M.Pharm'),
#  (0.0028839075864174977, 'Degree_MA'),
#  (0.0028357943877641264, 'Degree_MD'),
#  (0.0028320908680754104, 'Degree_MBA'),
#  (0.002826139160230609, 'City_Kanpur'),
#  (0.002810410186289653, 'Degree_M.Com'),
#  (0.0027976944895629, 'City_Nashik'),
#  (0.0027029944860542375, 'City_Varanasi'),
#  (0.0025804893664055726, 'Degree_PhD'),
#  (0.0025509421198401105, 'City_Faridabad'),
#  (0.002466094719697287, 'Degree_LLM'),
#  (0.0013714703969828876, 'Degree_ME'),
#  (0.0012502651009858605, 'Degree_MHM'),
#  (0.00033105568969478676, 'Degree_Others'),
#  (0.00020825838703923653, 'Profession_Student'),
#  (0.0001328498183047882, 'Dietary Habits_Others'),
#  (0.00010503244821311309, 'Sleep Duration_Others'),
#  (6.568001002532408e-05, 'Financial Stress_?'),
#  (5.7663104742587e-05, 'Profession_Architect'),
#  (5.3794718235053673e-05, 'City_Nalyan'),
#  (5.0079481839587604e-05, 'Job Satisfaction'),
#  (4.21802515560888e-05, 'Profession_Doctor'),
#  (2.6499717610663748e-05, 'City_Nandini'),
#  (2.322371386922035e-05, 'City_Saanvi'),
#  (2.274840471114273e-05, "Profession_'Digital Marketer'"),
#  (2.0778267985193196e-05, 'Work Pressure'),
#  (2.049258251459821e-05, 'Profession_Teacher'),
#  (1.662082163000493e-05, 'Profession_Manager'),
#  (1.6339088699475032e-05, 'City_Bhavna'),
#  (1.5675770213139532e-05, 'City_ME'),
#  (1.5301896291453164e-05, 'City_Mira'),
#  (1.3777281956699212e-05, 'City_Vaanya'),
#  (8.99104541134718e-06, 'Profession_Chef'),
#  (8.761271145095435e-06, 'City_Reyansh'),
#  (5.381136129504039e-06, 'City_City'),
#  (5.042604399816817e-06, "Profession_'UX/UI Designer'"),
#  (3.5178323317777593e-06, 'City_Harsha'),
#  (3.4319494098992675e-06, "Profession_'Content Writer'"),
#  (2.504583884414015e-06, 'City_Mihir'),
#  (2.4162786793794817e-06, "City_'Less Delhi'"),
#  (1.796687424502588e-06, 'City_Rashi'),
#  (1.3262272234816328e-06, "Profession_'Civil Engineer'"),
#  (1.0931889700253468e-06, 'Profession_Lawyer'),
#  (7.227018076581636e-07, 'City_Harsh'),
#  (6.018948630775428e-07, 'City_3.0'),
#  (5.578005187597665e-07, 'Profession_Pharmacist'),
#  (1.1730082895640286e-09, 'City_Gaurav'),
#  (0.0, 'Profession_Entrepreneur'),
#  (0.0, "Profession_'Educational Consultant'"),
#  (0.0, 'City_Nalini'),
#  (0.0, 'City_M.Tech'),
#  (0.0, 'City_M.Com'),
#  (0.0, 'City_Kibara'),
#  (0.0, 'City_Khaziabad'),
#  (0.0, "City_'Less than 5 Kalyan'")]

# %%
# Save model to file for flask api use
joblib.dump(rf_model, "../api/model.h5")
